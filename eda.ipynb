# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'D:\Datasets\Loan Dataset.csv')

# %%
data.head()
# Out:
#    Loan_ID  Gender Married Dependents   Education   Self_Employed  \
# 0  LP001002  Male      No       0          Graduate        No
# 1  LP001003  Male     Yes       1          Graduate        No
# 2  LP001005  Male     Yes       0          Graduate       Yes
# 3  LP001006  Male     Yes       0      Not Graduate        No
# 4  LP001008  Male      No       0          Graduate        No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0       5849                0.0             NaN          360.0
# 1       4583             1508.0           128.0          360.0
# 2       3000                0.0            66.0          360.0
# 3       2583             2358.0           120.0          360.0
# 4       6000                0.0           141.0          360.0
#
#    Credit_History Property_Area Loan_Status
# 0        1.0           Urban          Y
# 1        1.0           Rural          N
# 2        1.0           Urban          Y
# ...

# %% [markdown]
# # Automated

# %%
import sweetviz as sv  #web page
report = sv.analyze(data)
report.show_html('report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from autoviz.AutoViz_Class import AutoViz_Class # On the Notebook
AV=AutoViz_Class()
import matplotlib.pyplot as plt
# %matplotlib inline
filename="D:\Datasets\Loan Dataset.csv"
sep= ","
df=AV.AutoViz(
    filename
    )
# Out:
# Shape of your Data Set loaded: (614, 13)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  3
#     Number of Integer-Categorical Columns =  1
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  5
#     Number of Numeric-Boolean Columns =  1
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     13 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Loan_ID']
# ...

# %% [markdown]
# # Seaborn EDA

# %%
sns.scatterplot(data=data,x='Loan_Amount_Term',y='ApplicantIncome')#Used to show the relationship between two variables.
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='ApplicantIncome'>

# %%
sns.lineplot(data=data,x='Loan_Amount_Term',y='ApplicantIncome')#Used to show trends over time or ordered variables.
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='ApplicantIncome'>

# %%
sns.histplot(data['Education'])   #use to plot catagorical as well as nuemrical var , distribution of single variable
# Out:
# <Axes: xlabel='Education', ylabel='Count'>

# %%
sns.kdeplot(data['ApplicantIncome'])  #for continious variable   Kernel Density Estimate plot
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
sns.barplot(data=data,y='ApplicantIncome',x='Gender') #Used to show the distribution of categorical data.
# Out:
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>

# %%
sns.boxplot(data['ApplicantIncome']) #outliers
# Out:
# <Axes: ylabel='ApplicantIncome'>

# %%
sns.boxplot(data=data,y='ApplicantIncome',x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>

# %%
sns.pairplot(data)#Used to visualize pairwise relationships in a dataset.

# %%
g = sns.FacetGrid(data, col='Gender')
g.map(sns.scatterplot, 'ApplicantIncome', 'LoanAmount')#Used to plot multiple subplots based on a categorical variable

# %%
sns.lmplot(data=data ,x='ApplicantIncome',y='LoanAmount') #Used for plotting linear relationships, including regression lines.
